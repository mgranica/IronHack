# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import folium
import pandas as pd
import geopandas
from geopandas import gpd

# %%
acc_gnr= pd.read_csv('https://opendata-ajuntament.barcelona.cat/data/dataset/87aa433e-fef8-4ff4-8f9a-d66e9beefff6/resource/c6b05180-8084-4d89-a80c-f56de1f8e4de/download/2018_accidents_persones_gu_bcn_.csv')
acc_gnr.head()
# Out:
#   Numero_expedient  Codi_districte   Nom_districte  Codi_barri  \
# 0  2018S000001                   3  Sants-Montjuïc          11
# 1  2018S000001                   3  Sants-Montjuïc          11
# 2  2018S000002                   2        Eixample           9
# 3  2018S000003                  10      Sant Martí          64
# 4  2018S000005                   8      Nou Barris          56
#
#                         Nom_barri  Codi_carrer  \
# 0                    el Poble-sec       273400
# 1                    el Poble-sec       273400
# 2  la Nova Esquerra de l'Eixample       361406
# 3      el Camp de l'Arpa del Clot       161407
# 4                        Vallbona       330606
#
#                                           Nom_carrer Num_postal   \
# 0  Paral·lel                                     ...  117-119
# 1  Paral·lel                                     ...         NaN
# 2  Viladomat / Rosselló                          ...         NaN
# ...

# %%
acc_veh_18 = pd.read_csv('https://opendata-ajuntament.barcelona.cat/data/dataset/317e3743-fb79-4d2f-a128-5f12d2c9a55a/resource/6e2daeb5-e359-43ad-b0b5-7fdf438c8d6f/download/2018_accidents_vehicles_gu_bcn_.csv')
acc_veh_18
# Out:
#         Codi_expedient  Codi_districte Nom_districte  Codi_barri  \
# 0      2018S007344                   1  Ciutat Vella           1
# 1      2018S009617                   1  Ciutat Vella           1
# 2      2018S008382                   1  Ciutat Vella           2
# 3      2018S002684                   1  Ciutat Vella           2
# 4      2018S004886                   1  Ciutat Vella           2
# ...                ...             ...           ...         ...
# 19074  2018S006251                  10    Sant Martí          73
# 19075  2018S006492                  10    Sant Martí          73
# 19076  2018S006492                  10    Sant Martí          73
# 19077  2018S006492                  10    Sant Martí          73
# 19078  2018S009754                  10    Sant Martí          73
#
#                  Nom_barri  Codi_carrer  \
# 0                 el Raval       269108
# 1                 el Raval       701265
# 2           el Barri Gòtic        34308
# ...

# %%
acc_veh_18.columns
# Out:
# Index(['Codi_expedient', 'Codi_districte', 'Nom_districte', 'Codi_barri',
#        'Nom_barri', 'Codi_carrer', 'Nom_carrer', 'Num_postal ',
#        'Descripcio_dia_setmana', 'Dia_setmana', 'Descripcio_tipus_dia', 'Any',
#        'Mes_any', 'Nom_mes', 'Dia_mes', 'Hora_dia', 'Descripcio_torn',
#        'Descripcio_causa_vianant', 'Descripcio_tipus_vehicle',
#        'Descripcio_model', 'Descripcio_marca', 'Descripcio_color',
#        'Descripcio_carnet', 'Antiguitat_carnet', 'Coordenada_UTM_X',
#        'Coordenada_UTM_Y', 'Longitud', 'Latitud'],
#       dtype='object')

# %%
acc_veh_18.loc[~(acc_veh_18['Descripcio_dia_setmana']=='Diumenge')|(acc_veh_18['Descripcio_dia_setmana']=='Dissabte'),'Descripcio_tipus_dia']='Laboral'

# %%
acc_veh_18.Descripcio_tipus_dia.value_counts()
# Out:
# Laboral         15316
# Finde semana     3763
# Name: Descripcio_tipus_dia, dtype: int64

# %%
acc_veh_18.to_csv('accidentes_2018.csv')

# %%
acc_turismes = acc_veh_18.loc[acc_veh_18['Descripcio_tipus_vehicle']=='Turisme']

# %%
acc_turismes.Descripcio_marca.unique()
# Out:
# array(['SEAT', 'PEUGEOT', 'RENAULT', 'Desconegut', 'FORD', 'BMW',
#        'A.U.D.I.', 'OPEL', 'KIA', 'VOLKSWAGEN', 'SKODA', 'MERCEDES',
#        'LANCIA', 'AUDI', 'FIAT', 'TOYOTA', 'MAZDA', 'CITROEN', 'DAEWOO',
#        'A U D I', 'DACIA', 'DODGE', 'NISSAN', 'HONDA', 'HYUNDAI', 'MINI',
#        'ALFA ROMEO', 'LAND ROVER', 'SUZUKI', 'SMART', 'VOLVO', 'JEEP',
#        'TATA', 'LEXUS', 'PORSCHE', 'MITSUBISHI', 'CHEVROLET', 'B.M.W.',
#        'CHRYSLER', 'ES DESCONEIX', 'JAGUAR', 'SSANGYONG', 'SAAB',
#        'SUBARU', 'INFINITI', 'IRISBUS', 'MERCEDES-BENZ', 'PIAGGIO',
#        'JAGUAR LAND ROV', 'LEONART', 'B M W', 'MECEDES', 'ROVER',
#        'IVECO FIAT', 'FERRARI', 'MASERATI', 'MERCEDES B', 'BERGADANA',
#        'S.Y.M', 'APRILIA', 'IVECO BUS', 'KYMCO', 'LINCOLN', 'GALLOPER',
#        'TECNUVE'], dtype=object)

# %%
acc_turismes.groupby('Descripcio_marca',as_index=False).sum()
# Out:
#    Descripcio_marca  Codi_districte  Codi_barri  Codi_carrer      Any  \
# 0           A U D I             201        1125      8551727    82738
# 1          A.U.D.I.             103         578      4993406    42378
# 2        ALFA ROMEO             181        1048     12975591    70630
# 3           APRILIA               2           6        89004     2018
# 4              AUDI            1911       10637     99004186   778948
# ..              ...             ...         ...          ...      ...
# 60             TATA               2           9       100800     2018
# 61          TECNUVE               4          21       213806     2018
# 62           TOYOTA            1627        9174     76785830   643742
# 63       VOLKSWAGEN            3811       21307    222787116  1555878
# 64            VOLVO             434        2366     25696844   191710
#
#     Mes_any  Dia_mes  Hora_dia  Coordenada_UTM_X  Coordenada_UTM_Y  \
# ...

# %%
acc_turismes.loc[acc_turismes['Descripcio_marca']=='A.U.D.I.', 'Descripcio_marca']='AUDI'
acc_turismes.loc[acc_turismes['Descripcio_marca']=='A U D I', 'Descripcio_marca']='AUDI'

# %%
acc_turismes.loc[acc_turismes['Descripcio_marca']=='B M W']='BMW'
acc_turismes.loc[acc_turismes['Descripcio_marca']=='B.M.W']='BMW'
# Out:
# c:\program files\python38\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-15-2ce24d81f1d2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   acc_turismes.loc[acc_turismes['Descripcio_marca']=='B.M.W']='BMW'

# %%
acc_turismes.Descripcio_marca.unique
# Out:
# <bound method Series.unique of 0              SEAT
# 1           PEUGEOT
# 6           RENAULT
# 8        Desconegut
# 9              FORD
#             ...
# 19074          OPEL
# 19075       PEUGEOT
# 19076       CITROEN
# 19077          MINI
# 19078          AUDI
# Name: Descripcio_marca, Length: 7707, dtype: object>

# %%
acc_motos = acc_veh_18[acc_veh_18['Descripcio_tipus_vehicle']=='Moto']

# %%
acc_motos.Descripcio_marca.unique()
# Out:
# array([], dtype=object)
