# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.figure(figsize=(8,8))
x = x
y = y
plt.plot(x,y, 'dodgerblue', label='square line', linewidth=2)
plt.title('X line')
#plt.xlabel(x, fontsize=15)
#plt.ylabel(y, fontsize=15)
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

# Creates just a figure and only one subplot
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Simple plot')

# Creates two subplots and unpacks the output array immediately
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)

# Creates four polar axes, and accesses them through the returned array
fig, axes = plt.subplots(2, 2, subplot_kw=dict(polar=True))
axes[0, 0].plot(x, y)
axes[1, 1].scatter(x, y)

# Share a X axis with each column of subplots
plt.subplots(2, 2, sharex='col')

# Share a Y axis with each row of subplots
plt.subplots(2, 2, sharey='row')

# Share both X and Y axes with all subplots
plt.subplots(2, 2, sharex='all', sharey='all')

# Note that this is the same as
plt.subplots(2, 2, sharex=True, sharey=True)

# Creates figure number 10 with a single subplot
# and clears it if it already exists.
fig, ax=plt.subplots(num=10, clear=True
# Out:
#   File "<ipython-input-4-6a951ccd481a>", line 35
#     fig, ax=plt.subplots(num=10, clear=True
#                                            ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ### Creates two subplots and unpacks the output array immediately

# %%
# Method 2
f, (ax1, ax2)= plt.subplots(nrows=1, ncols=2)
ax1.plot(x, y)
ax1.set_title('X line')
ax2.hist(z)
ax2.set_title('square root histogram')
# Out:
# Text(0.5, 1.0, 'square root histogram')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
f, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(8,5))
ax1.plot(x, y, color='k', alpha=0.3)
ax1.set_title('Y line')
ax2.plot(x, z)
ax2.set_title('Z curve')
# Out:
# Text(0.5, 1.0, 'Z curve')

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
import math

# %%
# your code here

# xscale/yscale {"linear", "log", "symlog", "logit", ...}
z = np.exp(x)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
ax1.plot(x,y)
ax1.set_title('y=x^2')
ax2.plot(x, z)
ax2.set_title('y=e^2')
ax2.set_xscale('log')
ax2.set_yscale('log')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
z = np.exp(x)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
ax1.plot(x,y, label='line')
ax1.set_title('y=x^2')
ax1.legend()
ax2.plot(x, z, label='curve')
ax2.set_title('y=e^2')
ax2.legend()
ax2.set_xscale('log')
ax2.set_yscale('log')

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
import pymysql

driver    ='mysql+pymysql:'
user      = 'root'
password  ='Tarradellas90'
ip        =':3306'
database  ='fitbit'

connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
conn = create_engine(connection_string)
print(connection_string)
print(conn)
# Out:
# mysql+pymysql://root:Tarradellas90@:3306/fitbit
# Engine(mysql+pymysql://root:***@:3306/fitbit)

# %%
df_fitbit2 = pd.read_sql('SELECT * from fitbit2', conn)
# Out:
# c:\program files\python38\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE1ndar ...' for column 'VARIABLE_VALUE' at row 485")
#   result = self._query(query)

# %%
df_fitbit2.head()
# Out:
#          Date  Calorie burned  Steps Distance  Floors Minutes Sedentary  \
# 0  2015-05-08            1934    905     0.65       0             1.355
# 1  2015-05-09            3631  18925    14.11       4               611
# 2  2015-05-10            3204  14228    10.57       1               602
# 3  2015-05-11            2673   6756     5.02       8               749
# 4  2015-05-12            2495    502     3.73       1               876
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
df_s_by_m = df_fitbit2[['Steps','Months_encoded']].groupby('Months_encoded', as_index= False).median()
x1 = df_s_by_m.Months_encoded
y1 = df_s_by_m.Steps

plt.plot(x1, y1, 'dodgerblue', linewidth=2)
plt.title('Median of steps by months')
plt.xlabel('Months encoded')
plt.ylabel('Steps')
# Out:
# Text(0, 0.5, 'Steps')

# %%
# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
df_s_by_w_w = df_fitbit2[['Steps','Work_or_Weekend']].groupby('Work_or_Weekend', as_index= False).median()
x2 = df_s_by_w_w.Work_or_Weekend
y2 = df_s_by_w_w.Steps

plt.bar(x2, y2)
plt.title('Median of steps by Work or Weekend')
plt.xlabel('Work or Weekend')
plt.ylabel('Steps')
# Out:
# Text(0, 0.5, 'Steps')

# %%
f, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
ax1.plot(x1, y1, label='curve')
ax1.legend()
ax1.set_title('Steps by months')
ax1.set_xlabel('Months encode')
ax1.set_ylabel('Steps')

ax2.bar(x2, y2, label='bars')
ax2.set_title('Steps by week')
ax2.set_xlabel('work/weekend')
ax2.set_ylabel('Steps')
# Out:
# Text(0, 0.5, 'Steps')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
to_plot = ['Minutes Lightly Active', 'Minutes Very Active','Minutes Sedentary']

f, ax = plt.subplots(3, 1, figsize=(18,12))

for col, axis in zip(to_plot, ax):
    
    axis.scatter(df_fitbit2[col], df_fitbit2['Steps'], s=df_fitbit2['Steps']/200, color='orange', edgecolor='black', alpha=0.5)
    axis.legend()
    axis.set_title('Steps by months')
    axis.set_xlabel(col)
    axis.set_ylabel('Steps')
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
import pymysql

driver    ='mysql+pymysql:'
user      = 'root'
password  ='Tarradellas90'
ip        =':3306'
database  ='titanic'

connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
conn = create_engine(connection_string)
print(connection_string)
print(conn)
# Out:
# mysql+pymysql://root:Tarradellas90@:3306/titanic
# Engine(mysql+pymysql://root:***@:3306/titanic)

# %%
df_titanic = pd.read_sql('SELECT * from titanic', conn)
df_titanic
# Out:
# c:\program files\python38\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xE1ndar ...' for column 'VARIABLE_VALUE' at row 485")
#   result = self._query(query)
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
df_titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic_numerical = df_titanic.select_dtypes(include=['int64','float64'])
titanic_numerical
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
titanic_categorical = df_titanic.select_dtypes(include=['object'])
titanic_categorical
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %%
import seaborn as sns
sns.pairplot(titanic_numerical)

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
import matplotlib.style
plt.style.use('classic')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.hist(df_titanic.Age, bins=10)
# Out:
# (array([ 72.,  78., 326., 347., 220., 136.,  75.,  42.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
f, ax  = plt.subplots(3, 1)
bin_size=[10, 20 , 50]
for b, axis in zip(bin_size, ax):
    axis.hist(df_titanic.Age, bins=b)
    axis.set_title(f'age distribution, bin:{b}')

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
by segementing the population it gives us a more granular analisis.
bigger bin --> bigger the detail
"""
# Out:
# '\nby segementing the population it gives us a more granular analisis.\nbigger bin --> bigger the detail\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

#gapminder['lifeExp'].hist(bins=100)
plt.style.use('default')
df_titanic['Age'].hist(bins=50)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.bar(df_titanic['Gender'], df_titanic['Gender'].count())
# Out:
# <BarContainer object of 1309 artists>

# %%
# Method 2 - seaborn
# your code here
#titanic = sns.load_dataset("titanic")
#sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic);
#ax = sns.barplot(x="day", y="total_bill", hue="sex", data=tips)

sns.countplot(x='Gender', data=df_titanic)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
ax = sns.countplot(x="Pclass", data=df_titanic)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.set(style="whitegrid")
sns.boxenplot(x=df_titanic['Age'])

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
i= df_titanic['Age']
x=pd.Series(df_titanic['Age'], name='variable')
sns.distplot(x)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter(df_titanic['Age'],df_titanic['Fare'], alpha=0.5, edgecolor='black')

# %%
# Method 2 - seaborn
# your code here
#ax = sns.scatterplot(x="total_bill", y="tip", hue="time",data=tips
sns.scatterplot(x='Age', y='Fare', data=df_titanic)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.heatmap(titanic_numerical.corr())

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.boxplot(x='Pclass', y='Age', data=df_titanic)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

sns.FacetGrid(df_titanic, col="Age",  hue="Gender")
